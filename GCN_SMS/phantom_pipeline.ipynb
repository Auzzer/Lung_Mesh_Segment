# %% [markdown]
# 1. pymlash mesh generation
# 2. fem solver via fencis
# 3. corrfield
# 4. sms forward solver and compare with the fem solver
#
# iterate the past 4 steps and generated sveral mehses.
#
# solve the inverse problem

# %% [markdown]
# # 1. pymlash mesh generation

# %% [markdown]
# 1. The experiment includes the whole pipeline from the ct image to the mapped ct image stiffness
#
# 2. I found a statement in your paper saying"Frequency properties and overall intensity bias of the textures were affected by the elasticity." Can I think of it because the algorithm pipeline is from the CT image intensity value to the CT image stiffness value? We use fft to generate the intensity value: higher E like tumor -> (absorb more xray)higher intensity -> lighter CT image; lower E like normal tissue -> lower intensity -> darker
